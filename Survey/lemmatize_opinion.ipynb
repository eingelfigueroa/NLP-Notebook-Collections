# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (3.5)
# Requirement already satisfied: click in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from nltk) (7.1.2)
# Requirement already satisfied: tqdm in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from nltk) (4.59.0)
# Requirement already satisfied: regex in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from nltk) (2021.3.17)
# Requirement already satisfied: joblib in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from nltk) (1.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import re
import nltk
from nltk import word_tokenize, pos_tag, pos_tag_sents

# %% [markdown]
# ### Import modules needed

# %%
nltk.download('vader_lexicon')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger') 
nltk.download('punkt')
nltk.download('wordnet')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords


from nltk.stem import WordNetLemmatizer 
from nltk.corpus import wordnet 
# Create WordNetLemmatizer object 

sid = SentimentIntensityAnalyzer()
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/jupyterlab/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/jupyterlab/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/jupyterlab/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to /home/jupyterlab/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/jupyterlab/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ### Customized POS Tagger

# %%
def pos_tagger(nltk_tag): 
    if nltk_tag.startswith('J'): 
        return wordnet.ADJ 
    elif nltk_tag.startswith('V'): 
        return wordnet.VERB 
    elif nltk_tag.startswith('N'): 
        return wordnet.NOUN 
    elif nltk_tag.startswith('R'): 
        return wordnet.ADV 
    else:           
        return None

# %%
df = pd.read_csv('opinion_survey.csv')
df = df.replace(np.nan, 'Neutral', regex=True) ### Some values are missing, use "Neutral" for missing values
df = df.drop(df.columns[[0]],axis=1) ### Drop extra index
test_df = df.iloc[0:, 0:] # Just for renaming purposes so that df variable can be used for testing
test_df
# Out:
#     I can easily log-in and log-out my Canvas account. (Please write your views relating your answer above.)  \
# 0                                                i can
# 1                        i have no problems in log in
# 2                           I have no problems with it
# 3                     i dont have problem in my canvas
# 4                                   i have no problems
# ..                                                 ...
# 135                        I have no problem with that
# 136                                     strongly agree
# 137                                                Yes
# 138  There are some times where i cant log in when ...
# 139                                                yes
#
#     I can access my course using the mobile Canvas app. (Please write your views about this relating to your answer above.)  \
# 0                                                i can
# 1                                    i have no problem
# 2                          I have no problems with it
# 3    i can easily login my canvas app in my mobile app
# 4                               i can access my course
# ..                                                 ...
# 135                        I have no problem with that
# 136                                     strongly agree
# 137                                                yes
# 138                                    No problem here
# 139                                                yes
#
#     I can access my Canvas account using the available computers in JRU. (Please write your views about this relating to your answer above.)  \
# 0                                                i can
# 1                                    i have no problem
# 2                          I have no problems with it
# 3    I can access my Canvas account using the avail...
# 4                    no problem in accessing my canvas
# ..                                                 ...
# 135                                   Yes I can access
# 136                                     strongly agree
# 137                                                yes
# 138                                    No problem here
# 139                                                yes
#
#     I have no issues accessing my Canvas account using the wired internet connection in the computer laboratories. (Please write your views about this relating to your answer above.)  \
# 0                                                i can
# 1                                    i have no problem
# 2                           I have no problems with it
# 3           i dont have problem in internet connection
# 4                                      dont have issue
# ..                                                 ...
# 135                    Sometimes it takes time to load
# 136                                     strongly agree
# 137                                                yes
# 138                                    No problem here
# 139                                                yes
#
#     I can easily get help when I have problems with my Canvas account. (Please write your views about this relating to your answer above.)  \
# 0                                                i can
# 1                                    i have no problem
# 2                           I have no problems with it
# 3                          i dont have problem with it
# 4                                     no problem with
# ..                                                 ...
# 135  Yes, the people in IT office is always ready t...
# 136                                     strongly agree
# 137                                                yes
# 138                The guys at itbl gets the job done.
# 139                                                yes
#
#     I can access my Canvas account outside JRU. (Please write your views about this relating to your answer above.)  \
# 0                                                i can
# 1                                    i have no problem
# 2                           I have no problems with it
# 3                          i dont have problem with it
# 4                                           no problem
# ..                                                 ...
# 135                        I have no problem with that
# 136                                     strongly agree
# 137                                                yes
# 138                            Sometimes i cant log in
# 139                                                yes
#
#     I can clearly understand the lessons on my Canvas modules. (Please write your views about this relating to your answer above.)  \
# 0                                                i can
# 1                                    i have no problem
# 2                           I have no problems with it
# 3                          i dont have problem with it
# 4                                         i understand
# ..                                                 ...
# 135                             Yes its clearly for me
# 136                                     strongly agree
# 137                                                yes
# 138                                                Yes
# 139                                                yes
#
#     I recognize that the modules in my course are well organized. (Please write your views about this relating to your answer above.)  \
# 0                                                i can
# 1                                    i have no problem
# 2                           I have no problems with it
# 3                          i dont have problem with it
# 4                                    easy to recognize
# ..                                                 ...
# 135                            Yes it's well organized
# 136                                     strongly agree
# 137                                                yes
# 138                                                Yes
# 139                                                yes
#
#     I can easily manage the navigation of the courses through the desktop version. .1  \
# 0                                                i can
# 1                                    i have no problem
# 2                           I have no problems with it
# 3                          i dont have problem with it
# 4                                         i can manage
# ..                                                 ...
# 135                        I have no problem with that
# 136                                     strongly agree
# 137                                                yes
# 138                                                Yes
# 139                                                yes
#
#     I can easily manage the navigation of the courses through the mobile app. (Please write your views about this relating to your answer above.)  \
# 0                                                i can
# 1                                    i have no problem
# 2                           I have no problems with it
# 3                          i dont have problem with it
# 4                                         i can manage
# ..                                                 ...
# 135                        I have no problem with that
# 136                                     strongly agree
# 137                                                yes
# 138                                                Yes
# 139                                                yes
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 135  ...
# 136  ...
# 137  ...
# 138  ...
# 139  ...
#
#     I understand the lessons better with the help of course materials in Canvas. (Please write your views about this relating to your answer above.)  \
# 0                                                i can
# 1                                    i have no problem
# 2                           I have no problems with it
# 3                          i dont have problem with it
# 4                              i understand the lesson
# ..                                                 ...
# 135                           Yes I clearly understand
# 136                                     strongly agree
# 137                                                yes
# 138                                                Yes
# 139                                                yes
#
#     Canvas course materials make me interested. (Please write your views about this relating to your answer above.)  \
# 0                                                i can
# 1                                    i have no problem
# 2                           I have no problems with it
# 3                          i dont have problem with it
# 4                                        im interested
# ..                                                 ...
# 135                                   It's interesting
# 136                                     strongly agree
# 137                                                yes
# 138                                                Yes
# 139                                                yes
#
#     The course materials on Canvas helped me prepare for: Face to face discussions, quizzes, major exams, assignments, forums, etc. (Please write your views about this relating to your answer above.)  \
# 0                                                i can
# 1                                    i have no problem
# 2                           I have no problems with it
# 3                          i dont have problem with it
# 4                       the course materials helped me
# ..                                                 ...
# 135                        I have no problem with that
# 136                                     strongly agree
# 137                                                yes
# 138                                                Yes
# 139                                                yes
#
#     My instructor knows how to use Canvas. (Please write your views about this relating to your answer above.)  \
# 0                                                i can
# 1                                    i have no problem
# 2                           I have no problems with it
# 3                          i dont have problem with it
# 4                                 yes she teach us how
# ..                                                 ...
# 135                                      Yes she knows
# 136                                     strongly agree
# 137                                                yes
# 138                                                Yes
# 139                                                yes
#
#     My instructor demonstrated mastery of the subject matter. (Please write your views about this relating to your answer above.)  \
# 0                                                i can
# 1                                    i have no problem
# 2                           I have no problems with it
# 3                          i dont have problem with it
# 4                                  yes she demonstrate
# ..                                                 ...
# 135                            Yes she's teaching well
# 136                                     strongly agree
# 137                                                yes
# 138                                                Yes
# 139                                                yes
#
#     My instructor encourages me to use Canvas. (Please write your views about this relating to your answer above.)  \
# 0                                                i can
# 1                                    i have no problem
# 2                           I have no problems with it
# 3                          i dont have problem with it
# 4                                     she encourage me
# ..                                                 ...
# 135             Yes because some forums need to answer
# 136                                     strongly agree
# 137                                                yes
# 138                                                Yes
# 139                                                yes
#
#     Canvas has made it easy for me to: communicate with my instructor, receive class announcements, share ideas on group discussions  \
# 0                                                i can
# 1                                    i have no problem
# 2                           I have no problems with it
# 3                          i dont have problem with it
# 4                               i can communicate easy
# ..                                                 ...
# 135                        I have no problem with that
# 136                                     strongly agree
# 137                                                yes
# 138                                                Yes
# 139                                                yes
#
#     I can answer the assessment materials (quiz, exam) posted in Canvas. (Please write your views about this relating to your answer above.)  \
# 0                                                i can
# 1                                    i have no problem
# 2                           I have no problems with it
# 3                          i dont have problem with it
# 4                            i have no problem with it
# ..                                                 ...
# 135                                          Yes I can
# 136                                     strongly agree
# 137                                                yes
# 138                                                Yes
# 139                                                yes
#
#     I find the course materials on Canvas aligned with the: quizzes, major exams, assignments, forums, etc.) (Please write your views about this relating to your answer above.)  \
# 0                                                i can
# 1                                    i have no problem
# 2                           I have no problems with it
# 3                          i dont have problem with it
# 4                            i have no problem with it
# ..                                                 ...
# 135                        I have no problem with that
# 136                                     strongly agree
# 137                                                yes
# 138                                                Yes
# 139                                                yes
#
#     I have been give enough time to accomplish the activities on Canvas. (Please write your views about this relating to your answer above.)
# 0                                                    -
# 1                                    i have no problem
# 2                      Yes, I have no problems with it
# 3                          i dont have problem with it
# 4                            i have no problem with it
# ..                                                 ...
# 135             Yes sometimes she extends the deadline
# 136                                     strongly agree
# 137                                                yes
# 138                                                Yes
# 139                                                yes
#
# [140 rows x 21 columns]

# %%
stoplist = stopwords.words('english') + ['though']
def remove_stopWords(w): 
    w = ' '.join(word for word in w.split() if word not in stoplist)
    return w

# %%
col_range = len(test_df.columns) # number of columns
stored_pos = []
for i in range(0,col_range):
    col = test_df.columns[i] # The current column
    test_df.loc[:,col] = test_df[col].apply(lambda x : str.lower(str(x))) ## To Lower Case
    test_df.loc[:,col] = test_df[col].apply(lambda x : " ".join(re.findall('[\w]+',x))) # Remove Punctuations
    test_df.loc[:,col] = test_df[col].apply(lambda x : remove_stopWords(x)) # Remove Stop words
    
    ##POS TAGGING
    texts = test_df.loc[:,col].tolist()
    tagged_texts = pos_tag_sents(map(word_tokenize, texts)) ### Tag every word in a row with POS
    
    ### Lemmatization
    new = []

    stored_pos.append(tagged_texts)
    for i in tagged_texts:
        #if len(i) > 0:
        lemmatized_sentence = []
        for word, tag in i:
            tag = pos_tagger(tag) ### Convert POS Tag to known POS for simplification
            if tag is None: 
    # if there is no available tag, append the token as is 
                lemmatized_sentence.append(word) 
            else:         
    # else use the tag to lemmatize the token 
                lemmatized_sentence.append(lemmatizer.lemmatize(word, tag)) 

        lemmatized_sentence = " ".join(lemmatized_sentence) 
        #print(lemmatized_sentence)
        new.append(lemmatized_sentence)
        
    else:
        pass
    
    
    test_df['POS'] = new ## Store tagged words
    
    
test_df = test_df.replace(r'^\s*$', "neutral", regex=True) ## If row value is null, replace with neutral string
test_df
# Out:
#     I can easily log-in and log-out my Canvas account. (Please write your views relating your answer above.)  \
# 0                                              neutral
# 1                                         problems log
# 2                                             problems
# 3                                  dont problem canvas
# 4                                             problems
# ..                                                 ...
# 135                                            problem
# 136                                     strongly agree
# 137                                                yes
# 138  times cant log use computers troubling since t...
# 139                                                yes
#
#     I can access my course using the mobile Canvas app. (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                   easily login canvas app mobile app
# 4                                        access course
# ..                                                 ...
# 135                                            problem
# 136                                     strongly agree
# 137                                                yes
# 138                                            problem
# 139                                                yes
#
#     I can access my Canvas account using the available computers in JRU. (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3    access canvas account using available computer...
# 4                             problem accessing canvas
# ..                                                 ...
# 135                                         yes access
# 136                                     strongly agree
# 137                                                yes
# 138                                            problem
# 139                                                yes
#
#     I have no issues accessing my Canvas account using the wired internet connection in the computer laboratories. (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                     dont problem internet connection
# 4                                           dont issue
# ..                                                 ...
# 135                          sometimes takes time load
# 136                                     strongly agree
# 137                                                yes
# 138                                            problem
# 139                                                yes
#
#     I can easily get help when I have problems with my Canvas account. (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                                         dont problem
# 4                                              problem
# ..                                                 ...
# 135                yes people office always ready help
# 136                                     strongly agree
# 137                                                yes
# 138                            guys itbl gets job done
# 139                                                yes
#
#     I can access my Canvas account outside JRU. (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                                         dont problem
# 4                                              problem
# ..                                                 ...
# 135                                            problem
# 136                                     strongly agree
# 137                                                yes
# 138                                 sometimes cant log
# 139                                                yes
#
#     I can clearly understand the lessons on my Canvas modules. (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                                         dont problem
# 4                                           understand
# ..                                                 ...
# 135                                        yes clearly
# 136                                     strongly agree
# 137                                                yes
# 138                                                yes
# 139                                                yes
#
#     I recognize that the modules in my course are well organized. (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                                         dont problem
# 4                                       easy recognize
# ..                                                 ...
# 135                                 yes well organized
# 136                                     strongly agree
# 137                                                yes
# 138                                                yes
# 139                                                yes
#
#     I can easily manage the navigation of the courses through the desktop version. .1  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                                         dont problem
# 4                                               manage
# ..                                                 ...
# 135                                            problem
# 136                                     strongly agree
# 137                                                yes
# 138                                                yes
# 139                                                yes
#
#     I can easily manage the navigation of the courses through the mobile app. (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                                         dont problem
# 4                                               manage
# ..                                                 ...
# 135                                            problem
# 136                                     strongly agree
# 137                                                yes
# 138                                                yes
# 139                                                yes
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 135  ...
# 136  ...
# 137  ...
# 138  ...
# 139  ...
#
#     Canvas course materials make me interested. (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                                         dont problem
# 4                                        im interested
# ..                                                 ...
# 135                                        interesting
# 136                                     strongly agree
# 137                                                yes
# 138                                                yes
# 139                                                yes
#
#     The course materials on Canvas helped me prepare for: Face to face discussions, quizzes, major exams, assignments, forums, etc. (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                                         dont problem
# 4                              course materials helped
# ..                                                 ...
# 135                                            problem
# 136                                     strongly agree
# 137                                                yes
# 138                                                yes
# 139                                                yes
#
#     My instructor knows how to use Canvas. (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                                         dont problem
# 4                                         yes teach us
# ..                                                 ...
# 135                                          yes knows
# 136                                     strongly agree
# 137                                                yes
# 138                                                yes
# 139                                                yes
#
#     My instructor demonstrated mastery of the subject matter. (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                                         dont problem
# 4                                      yes demonstrate
# ..                                                 ...
# 135                                  yes teaching well
# 136                                     strongly agree
# 137                                                yes
# 138                                                yes
# 139                                                yes
#
#     My instructor encourages me to use Canvas. (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                                         dont problem
# 4                                            encourage
# ..                                                 ...
# 135                             yes forums need answer
# 136                                     strongly agree
# 137                                                yes
# 138                                                yes
# 139                                                yes
#
#     Canvas has made it easy for me to: communicate with my instructor, receive class announcements, share ideas on group discussions  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                                         dont problem
# 4                                     communicate easy
# ..                                                 ...
# 135                                            problem
# 136                                     strongly agree
# 137                                                yes
# 138                                                yes
# 139                                                yes
#
#     I can answer the assessment materials (quiz, exam) posted in Canvas. (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                                         dont problem
# 4                                              problem
# ..                                                 ...
# 135                                                yes
# 136                                     strongly agree
# 137                                                yes
# 138                                                yes
# 139                                                yes
#
#     I find the course materials on Canvas aligned with the: quizzes, major exams, assignments, forums, etc.) (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                                         dont problem
# 4                                              problem
# ..                                                 ...
# 135                                            problem
# 136                                     strongly agree
# 137                                                yes
# 138                                                yes
# 139                                                yes
#
#     I have been give enough time to accomplish the activities on Canvas. (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                         yes problems
# 3                                         dont problem
# 4                                              problem
# ..                                                 ...
# 135                     yes sometimes extends deadline
# 136                                     strongly agree
# 137                                                yes
# 138                                                yes
# 139                                                yes
#
#                                POS
# 0                          neutral
# 1                          problem
# 2                      yes problem
# 3                     dont problem
# 4                          problem
# ..                             ...
# 135  yes sometimes extend deadline
# 136                 strongly agree
# 137                            yes
# 138                            yes
# 139                            yes
#
# [140 rows x 22 columns]

# %%
test_df.to_csv('lemmatized_opinion.csv', index=False)

# %%
from pandas import DataFrame
col_name = test_df.columns.tolist()
ndf = DataFrame(stored_pos).transpose()
ndf.columns = col_name
ndf.to_csv('pos_tags.csv', index=False)

# %%
ndf
# Out:
#     I can easily log-in and log-out my Canvas account. (Please write your views relating your answer above.)  \
# 0                                      [(neutral, JJ)]
# 1                        [(problems, NNS), (log, VBP)]
# 2                                    [(problems, NNS)]
# 3            [(dont, NN), (problem, NN), (canvas, NN)]
# 4                                    [(problems, NNS)]
# ..                                                 ...
# 135                                    [(problem, NN)]
# 136                      [(strongly, RB), (agree, VB)]
# 137                                       [(yes, NNS)]
# 138  [(times, NNS), (cant, VBP), (log, NN), (use, N...
# 139                                       [(yes, NNS)]
#
#     I can access my course using the mobile Canvas app. (Please write your views about this relating to your answer above.)  \
# 0                                      [(neutral, JJ)]
# 1                                      [(problem, NN)]
# 2                                    [(problems, NNS)]
# 3    [(easily, RB), (login, VBZ), (canvas, NN), (ap...
# 4                         [(access, NN), (course, NN)]
# ..                                                 ...
# 135                                    [(problem, NN)]
# 136                      [(strongly, RB), (agree, VB)]
# 137                                       [(yes, NNS)]
# 138                                    [(problem, NN)]
# 139                                       [(yes, NNS)]
#
#     I can access my Canvas account using the available computers in JRU. (Please write your views about this relating to your answer above.)  \
# 0                                      [(neutral, JJ)]
# 1                                      [(problem, NN)]
# 2                                    [(problems, NNS)]
# 3    [(access, NN), (canvas, NN), (account, NN), (u...
# 4      [(problem, NN), (accessing, VBG), (canvas, NN)]
# ..                                                 ...
# 135                         [(yes, NNS), (access, NN)]
# 136                      [(strongly, RB), (agree, VB)]
# 137                                       [(yes, NNS)]
# 138                                    [(problem, NN)]
# 139                                       [(yes, NNS)]
#
#     I have no issues accessing my Canvas account using the wired internet connection in the computer laboratories. (Please write your views about this relating to your answer above.)  \
# 0                                      [(neutral, JJ)]
# 1                                      [(problem, NN)]
# 2                                    [(problems, NNS)]
# 3    [(dont, NN), (problem, NN), (internet, NN), (c...
# 4                            [(dont, JJ), (issue, NN)]
# ..                                                 ...
# 135  [(sometimes, RB), (takes, VBZ), (time, NN), (l...
# 136                      [(strongly, RB), (agree, VB)]
# 137                                       [(yes, NNS)]
# 138                                    [(problem, NN)]
# 139                                       [(yes, NNS)]
#
#     I can easily get help when I have problems with my Canvas account. (Please write your views about this relating to your answer above.)  \
# 0                                      [(neutral, JJ)]
# 1                                      [(problem, NN)]
# 2                                    [(problems, NNS)]
# 3                          [(dont, NN), (problem, NN)]
# 4                                      [(problem, NN)]
# ..                                                 ...
# 135  [(yes, RB), (people, NNS), (office, NN), (alwa...
# 136                      [(strongly, RB), (agree, VB)]
# 137                                       [(yes, NNS)]
# 138  [(guys, NNS), (itbl, VBP), (gets, VBZ), (job, ...
# 139                                       [(yes, NNS)]
#
#     I can access my Canvas account outside JRU. (Please write your views about this relating to your answer above.)  \
# 0                                      [(neutral, JJ)]
# 1                                      [(problem, NN)]
# 2                                    [(problems, NNS)]
# 3                          [(dont, NN), (problem, NN)]
# 4                                      [(problem, NN)]
# ..                                                 ...
# 135                                    [(problem, NN)]
# 136                      [(strongly, RB), (agree, VB)]
# 137                                       [(yes, NNS)]
# 138           [(sometimes, RB), (cant, JJ), (log, NN)]
# 139                                       [(yes, NNS)]
#
#     I can clearly understand the lessons on my Canvas modules. (Please write your views about this relating to your answer above.)  \
# 0                                      [(neutral, JJ)]
# 1                                      [(problem, NN)]
# 2                                    [(problems, NNS)]
# 3                          [(dont, NN), (problem, NN)]
# 4                                   [(understand, NN)]
# ..                                                 ...
# 135                        [(yes, NNS), (clearly, RB)]
# 136                      [(strongly, RB), (agree, VB)]
# 137                                       [(yes, NNS)]
# 138                                       [(yes, NNS)]
# 139                                       [(yes, NNS)]
#
#     I recognize that the modules in my course are well organized. (Please write your views about this relating to your answer above.)  \
# 0                                      [(neutral, JJ)]
# 1                                      [(problem, NN)]
# 2                                    [(problems, NNS)]
# 3                          [(dont, NN), (problem, NN)]
# 4                        [(easy, JJ), (recognize, VB)]
# ..                                                 ...
# 135          [(yes, RB), (well, RB), (organized, VBN)]
# 136                      [(strongly, RB), (agree, VB)]
# 137                                       [(yes, NNS)]
# 138                                       [(yes, NNS)]
# 139                                       [(yes, NNS)]
#
#     I can easily manage the navigation of the courses through the desktop version. .1  \
# 0                                      [(neutral, JJ)]
# 1                                      [(problem, NN)]
# 2                                    [(problems, NNS)]
# 3                          [(dont, NN), (problem, NN)]
# 4                                       [(manage, NN)]
# ..                                                 ...
# 135                                    [(problem, NN)]
# 136                      [(strongly, RB), (agree, VB)]
# 137                                       [(yes, NNS)]
# 138                                       [(yes, NNS)]
# 139                                       [(yes, NNS)]
#
#     I can easily manage the navigation of the courses through the mobile app. (Please write your views about this relating to your answer above.)  \
# 0                                      [(neutral, JJ)]
# 1                                      [(problem, NN)]
# 2                                    [(problems, NNS)]
# 3                          [(dont, NN), (problem, NN)]
# 4                                       [(manage, NN)]
# ..                                                 ...
# 135                                    [(problem, NN)]
# 136                      [(strongly, RB), (agree, VB)]
# 137                                       [(yes, NNS)]
# 138                                       [(yes, NNS)]
# 139                                       [(yes, NNS)]
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 135  ...
# 136  ...
# 137  ...
# 138  ...
# 139  ...
#
#     Canvas course materials make me interested. (Please write your views about this relating to your answer above.)  \
# 0                                      [(neutral, JJ)]
# 1                                      [(problem, NN)]
# 2                                    [(problems, NNS)]
# 3                          [(dont, NN), (problem, NN)]
# 4                         [(im, NN), (interested, JJ)]
# ..                                                 ...
# 135                               [(interesting, VBG)]
# 136                      [(strongly, RB), (agree, VB)]
# 137                                       [(yes, NNS)]
# 138                                       [(yes, NNS)]
# 139                                       [(yes, NNS)]
#
#     The course materials on Canvas helped me prepare for: Face to face discussions, quizzes, major exams, assignments, forums, etc. (Please write your views about this relating to your answer above.)  \
# 0                                      [(neutral, JJ)]
# 1                                      [(problem, NN)]
# 2                                    [(problems, NNS)]
# 3                          [(dont, NN), (problem, NN)]
# 4      [(course, NN), (materials, NNS), (helped, VBD)]
# ..                                                 ...
# 135                                    [(problem, NN)]
# 136                      [(strongly, RB), (agree, VB)]
# 137                                       [(yes, NNS)]
# 138                                       [(yes, NNS)]
# 139                                       [(yes, NNS)]
#
#     My instructor knows how to use Canvas. (Please write your views about this relating to your answer above.)  \
# 0                                      [(neutral, JJ)]
# 1                                      [(problem, NN)]
# 2                                    [(problems, NNS)]
# 3                          [(dont, NN), (problem, NN)]
# 4                  [(yes, RB), (teach, VB), (us, PRP)]
# ..                                                 ...
# 135                         [(yes, NNS), (knows, NNS)]
# 136                      [(strongly, RB), (agree, VB)]
# 137                                       [(yes, NNS)]
# 138                                       [(yes, NNS)]
# 139                                       [(yes, NNS)]
#
#     My instructor demonstrated mastery of the subject matter. (Please write your views about this relating to your answer above.)  \
# 0                                      [(neutral, JJ)]
# 1                                      [(problem, NN)]
# 2                                    [(problems, NNS)]
# 3                          [(dont, NN), (problem, NN)]
# 4                     [(yes, NNS), (demonstrate, VBP)]
# ..                                                 ...
# 135           [(yes, RB), (teaching, VBG), (well, RB)]
# 136                      [(strongly, RB), (agree, VB)]
# 137                                       [(yes, NNS)]
# 138                                       [(yes, NNS)]
# 139                                       [(yes, NNS)]
#
#     My instructor encourages me to use Canvas. (Please write your views about this relating to your answer above.)  \
# 0                                      [(neutral, JJ)]
# 1                                      [(problem, NN)]
# 2                                    [(problems, NNS)]
# 3                          [(dont, NN), (problem, NN)]
# 4                                    [(encourage, NN)]
# ..                                                 ...
# 135  [(yes, RB), (forums, NNS), (need, VBP), (answe...
# 136                      [(strongly, RB), (agree, VB)]
# 137                                       [(yes, NNS)]
# 138                                       [(yes, NNS)]
# 139                                       [(yes, NNS)]
#
#     Canvas has made it easy for me to: communicate with my instructor, receive class announcements, share ideas on group discussions  \
# 0                                      [(neutral, JJ)]
# 1                                      [(problem, NN)]
# 2                                    [(problems, NNS)]
# 3                          [(dont, NN), (problem, NN)]
# 4                      [(communicate, NN), (easy, NN)]
# ..                                                 ...
# 135                                    [(problem, NN)]
# 136                      [(strongly, RB), (agree, VB)]
# 137                                       [(yes, NNS)]
# 138                                       [(yes, NNS)]
# 139                                       [(yes, NNS)]
#
#     I can answer the assessment materials (quiz, exam) posted in Canvas. (Please write your views about this relating to your answer above.)  \
# 0                                      [(neutral, JJ)]
# 1                                      [(problem, NN)]
# 2                                    [(problems, NNS)]
# 3                          [(dont, NN), (problem, NN)]
# 4                                      [(problem, NN)]
# ..                                                 ...
# 135                                       [(yes, NNS)]
# 136                      [(strongly, RB), (agree, VB)]
# 137                                       [(yes, NNS)]
# 138                                       [(yes, NNS)]
# 139                                       [(yes, NNS)]
#
#     I find the course materials on Canvas aligned with the: quizzes, major exams, assignments, forums, etc.) (Please write your views about this relating to your answer above.)  \
# 0                                      [(neutral, JJ)]
# 1                                      [(problem, NN)]
# 2                                    [(problems, NNS)]
# 3                          [(dont, NN), (problem, NN)]
# 4                                      [(problem, NN)]
# ..                                                 ...
# 135                                    [(problem, NN)]
# 136                      [(strongly, RB), (agree, VB)]
# 137                                       [(yes, NNS)]
# 138                                       [(yes, NNS)]
# 139                                       [(yes, NNS)]
#
#     I have been give enough time to accomplish the activities on Canvas. (Please write your views about this relating to your answer above.)  \
# 0                                      [(neutral, JJ)]
# 1                                      [(problem, NN)]
# 2                         [(yes, RB), (problems, NNS)]
# 3                          [(dont, NN), (problem, NN)]
# 4                                      [(problem, NN)]
# ..                                                 ...
# 135  [(yes, NNS), (sometimes, RB), (extends, VBZ), ...
# 136                      [(strongly, RB), (agree, VB)]
# 137                                       [(yes, NNS)]
# 138                                       [(yes, NNS)]
# 139                                       [(yes, NNS)]
#
#                                                    POS
# 0                                      [(neutral, JJ)]
# 1                                      [(problem, NN)]
# 2                          [(yes, NNS), (problem, NN)]
# 3                          [(dont, NN), (problem, NN)]
# 4                                      [(problem, NN)]
# ..                                                 ...
# 135  [(yes, NNS), (sometimes, RB), (extend, VBP), (...
# 136                      [(strongly, RB), (agree, VB)]
# 137                                       [(yes, NNS)]
# 138                                       [(yes, NNS)]
# 139                                       [(yes, NNS)]
#
# [140 rows x 22 columns]

# %% [markdown]
# ### Sample POS Tags from first row

# %%
lem_df = pd.read_csv('lemmatized_opinion.csv')
lem_df = lem_df.iloc[0:, 0:-1] # Remove last columns
lem_df
# Out:
#     I can easily log-in and log-out my Canvas account. (Please write your views relating your answer above.)  \
# 0                                              neutral
# 1                                         problems log
# 2                                             problems
# 3                                  dont problem canvas
# 4                                             problems
# ..                                                 ...
# 135                                            problem
# 136                                     strongly agree
# 137                                                yes
# 138  times cant log use computers troubling since t...
# 139                                                yes
#
#     I can access my course using the mobile Canvas app. (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                   easily login canvas app mobile app
# 4                                        access course
# ..                                                 ...
# 135                                            problem
# 136                                     strongly agree
# 137                                                yes
# 138                                            problem
# 139                                                yes
#
#     I can access my Canvas account using the available computers in JRU. (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3    access canvas account using available computer...
# 4                             problem accessing canvas
# ..                                                 ...
# 135                                         yes access
# 136                                     strongly agree
# 137                                                yes
# 138                                            problem
# 139                                                yes
#
#     I have no issues accessing my Canvas account using the wired internet connection in the computer laboratories. (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                     dont problem internet connection
# 4                                           dont issue
# ..                                                 ...
# 135                          sometimes takes time load
# 136                                     strongly agree
# 137                                                yes
# 138                                            problem
# 139                                                yes
#
#     I can easily get help when I have problems with my Canvas account. (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                                         dont problem
# 4                                              problem
# ..                                                 ...
# 135                yes people office always ready help
# 136                                     strongly agree
# 137                                                yes
# 138                            guys itbl gets job done
# 139                                                yes
#
#     I can access my Canvas account outside JRU. (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                                         dont problem
# 4                                              problem
# ..                                                 ...
# 135                                            problem
# 136                                     strongly agree
# 137                                                yes
# 138                                 sometimes cant log
# 139                                                yes
#
#     I can clearly understand the lessons on my Canvas modules. (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                                         dont problem
# 4                                           understand
# ..                                                 ...
# 135                                        yes clearly
# 136                                     strongly agree
# 137                                                yes
# 138                                                yes
# 139                                                yes
#
#     I recognize that the modules in my course are well organized. (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                                         dont problem
# 4                                       easy recognize
# ..                                                 ...
# 135                                 yes well organized
# 136                                     strongly agree
# 137                                                yes
# 138                                                yes
# 139                                                yes
#
#     I can easily manage the navigation of the courses through the desktop version. .1  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                                         dont problem
# 4                                               manage
# ..                                                 ...
# 135                                            problem
# 136                                     strongly agree
# 137                                                yes
# 138                                                yes
# 139                                                yes
#
#     I can easily manage the navigation of the courses through the mobile app. (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                                         dont problem
# 4                                               manage
# ..                                                 ...
# 135                                            problem
# 136                                     strongly agree
# 137                                                yes
# 138                                                yes
# 139                                                yes
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 135  ...
# 136  ...
# 137  ...
# 138  ...
# 139  ...
#
#     I understand the lessons better with the help of course materials in Canvas. (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                                         dont problem
# 4                                    understand lesson
# ..                                                 ...
# 135                             yes clearly understand
# 136                                     strongly agree
# 137                                                yes
# 138                                                yes
# 139                                                yes
#
#     Canvas course materials make me interested. (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                                         dont problem
# 4                                        im interested
# ..                                                 ...
# 135                                        interesting
# 136                                     strongly agree
# 137                                                yes
# 138                                                yes
# 139                                                yes
#
#     The course materials on Canvas helped me prepare for: Face to face discussions, quizzes, major exams, assignments, forums, etc. (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                                         dont problem
# 4                              course materials helped
# ..                                                 ...
# 135                                            problem
# 136                                     strongly agree
# 137                                                yes
# 138                                                yes
# 139                                                yes
#
#     My instructor knows how to use Canvas. (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                                         dont problem
# 4                                         yes teach us
# ..                                                 ...
# 135                                          yes knows
# 136                                     strongly agree
# 137                                                yes
# 138                                                yes
# 139                                                yes
#
#     My instructor demonstrated mastery of the subject matter. (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                                         dont problem
# 4                                      yes demonstrate
# ..                                                 ...
# 135                                  yes teaching well
# 136                                     strongly agree
# 137                                                yes
# 138                                                yes
# 139                                                yes
#
#     My instructor encourages me to use Canvas. (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                                         dont problem
# 4                                            encourage
# ..                                                 ...
# 135                             yes forums need answer
# 136                                     strongly agree
# 137                                                yes
# 138                                                yes
# 139                                                yes
#
#     Canvas has made it easy for me to: communicate with my instructor, receive class announcements, share ideas on group discussions  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                                         dont problem
# 4                                     communicate easy
# ..                                                 ...
# 135                                            problem
# 136                                     strongly agree
# 137                                                yes
# 138                                                yes
# 139                                                yes
#
#     I can answer the assessment materials (quiz, exam) posted in Canvas. (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                                         dont problem
# 4                                              problem
# ..                                                 ...
# 135                                                yes
# 136                                     strongly agree
# 137                                                yes
# 138                                                yes
# 139                                                yes
#
#     I find the course materials on Canvas aligned with the: quizzes, major exams, assignments, forums, etc.) (Please write your views about this relating to your answer above.)  \
# 0                                              neutral
# 1                                              problem
# 2                                             problems
# 3                                         dont problem
# 4                                              problem
# ..                                                 ...
# 135                                            problem
# 136                                     strongly agree
# 137                                                yes
# 138                                                yes
# 139                                                yes
#
#     I have been give enough time to accomplish the activities on Canvas. (Please write your views about this relating to your answer above.)
# 0                                              neutral
# 1                                              problem
# 2                                         yes problems
# 3                                         dont problem
# 4                                              problem
# ..                                                 ...
# 135                     yes sometimes extends deadline
# 136                                     strongly agree
# 137                                                yes
# 138                                                yes
# 139                                                yes
#
# [140 rows x 21 columns]

# %%
comp = []
col_range = len(lem_df.columns) # number of columns

for i in range(0,col_range):
    col = test_df.columns[i] # The current column
    test_df['scores'] = test_df[col].apply(lambda x: sid.polarity_scores(x)) ## Get polarity score of every Column
    compound = test_df['scores'].apply(lambda score_dict: score_dict['compound']) ## Extract the compound from the results
    test_df = test_df.drop('scores', 1) # Drop score DF in every iteration
    compound = sum(compound)/140 # Get the mean compound of each columns
    comp.append(compound) # Save mean and append to list

# %%
from pprint import pprint

pprint(comp)
# Out:
# [0.17137571428571427,
#  0.16313071428571432,
#  0.15920571428571434,
#  0.08488142857142857,
#  0.2711971428571431,
#  0.17636500000000008,
#  0.26615285714285725,
#  0.27341714285714314,
#  0.31624142857142856,
#  0.25183285714285736,
#  0.20647571428571448,
#  0.33951142857142835,
#  0.37102928571428556,
#  0.2830335714285715,
#  0.24497928571428587,
#  0.2714250000000001,
#  0.2912928571428571,
#  0.2971407142857143,
#  0.2308800000000002,
#  0.206052142857143,
#  0.22575571428571445]

# %% [markdown]
# ## Comparisons

# %%
df_num = pd.read_csv('opinion_sentiment_score.csv')
cor_num = df_num.iloc[0:, 0:7:6]
cor_num
# Out:
#                                                 index  Sentiment Score
# 0   I can easily log-in and log-out my Canvas acco...         0.148826
# 1   I can access my course using the mobile Canvas...         0.140744
# 2   I can access my Canvas account using the avail...         0.141499
# 3   I can easily get help when I have problems wit...        -0.007863
# 4   I have no issues accessing my Canvas account u...         0.244604
# 5        I can access my Canvas account outside JRU.          0.155105
# 6   I can clearly understand the lessons on my Can...         0.228990
# 7   I recognize that the modules in my course are ...         0.242035
# 8   I can easily manage the navigation of the cour...         0.283602
# 9   I can easily manage the navigation of the cour...         0.210798
# 10  I notice that course materials on Canvas have ...         0.179135
# 11  I understand the lessons better with the help ...         0.335552
# 12        Canvas course materials make me interested.         0.341187
# 13  The course materials on Canvas helped me prepa...         0.254526
# 14             My instructor knows how to use Canvas.         0.217584
# 15  My instructor demonstrated mastery of the subj...         0.258990
# 16         My instructor encourages me to use Canvas.         0.284222
# 17  Canvas has made it easy for me to: [Communicat...         0.286009
# 18  I can answer the assessment materials (quiz, e...         0.215716
# 19  I find the course materials on Canvas aligned ...         0.180929
# 20  I have been give enough time to accomplish the...         0.196451

# %%
df_ngram = pd.read_csv('ngram_sentiment_score.csv')
#ngram_list = df_ngram.values.tolist()
ngram_list = df_ngram.values.flatten()

# %%
cor_num = cor_num.rename({'Sentiment Score': 'Without Lemmanization'}, axis=1) 
cor_num["With Lemmanization"] = comp
cor_num["Lemmatized and Ngram"] = ngram_list

cor_num.style.set_caption('Comparison of Sentiment Score results')
# Out:
# <style  type="text/css" >
# </style><table id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1" ><caption>Comparison of Sentiment Score results</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >Without Lemmanization</th>        <th class="col_heading level0 col2" >With Lemmanization</th>        <th class="col_heading level0 col3" >Lemmatized and Ngram</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row0_col0" class="data row0 col0" >I can easily log-in and log-out my Canvas account.</td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row0_col1" class="data row0 col1" >0.148826</td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row0_col2" class="data row0 col2" >0.171376</td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row0_col3" class="data row0 col3" >0.097426</td>
#             </tr>
#             <tr>
#                         <th id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row1_col0" class="data row1 col0" >I can access my course using the mobile Canvas app. </td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row1_col1" class="data row1 col1" >0.140744</td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row1_col2" class="data row1 col2" >0.163131</td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row1_col3" class="data row1 col3" >0.086712</td>
#             </tr>
#             <tr>
#                         <th id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row2_col0" class="data row2 col0" >I can access my Canvas account using the available computers in JRU.</td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row2_col1" class="data row2 col1" >0.141499</td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row2_col2" class="data row2 col2" >0.159206</td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row2_col3" class="data row2 col3" >0.084185</td>
#             </tr>
#             <tr>
#                         <th id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row3_col0" class="data row3 col0" >I can easily get help when I have problems with my Canvas account.</td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row3_col1" class="data row3 col1" >-0.007863</td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row3_col2" class="data row3 col2" >0.084881</td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row3_col3" class="data row3 col3" >0.026009</td>
#             </tr>
#             <tr>
#                         <th id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row4_col0" class="data row4 col0" >I have no issues accessing my Canvas account using the wired internet connection in the computer laboratories.</td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row4_col1" class="data row4 col1" >0.244604</td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row4_col2" class="data row4 col2" >0.271197</td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row4_col3" class="data row4 col3" >0.098726</td>
#             </tr>
#             <tr>
#                         <th id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row5_col0" class="data row5 col0" >I can access my Canvas account outside JRU. </td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row5_col1" class="data row5 col1" >0.155105</td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row5_col2" class="data row5 col2" >0.176365</td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row5_col3" class="data row5 col3" >0.068340</td>
#             </tr>
#             <tr>
#                         <th id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row6_col0" class="data row6 col0" >I can clearly understand the lessons on my Canvas modules. </td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row6_col1" class="data row6 col1" >0.228990</td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row6_col2" class="data row6 col2" >0.266153</td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row6_col3" class="data row6 col3" >0.155156</td>
#             </tr>
#             <tr>
#                         <th id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row7_col0" class="data row7 col0" >I recognize that the modules in my course are well organized.</td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row7_col1" class="data row7 col1" >0.242035</td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row7_col2" class="data row7 col2" >0.273417</td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row7_col3" class="data row7 col3" >0.203494</td>
#             </tr>
#             <tr>
#                         <th id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row8_col0" class="data row8 col0" >I can easily manage the navigation of the courses through the desktop version. </td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row8_col1" class="data row8 col1" >0.283602</td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row8_col2" class="data row8 col2" >0.316241</td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row8_col3" class="data row8 col3" >0.246295</td>
#             </tr>
#             <tr>
#                         <th id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row9_col0" class="data row9 col0" >I can easily manage the navigation of the courses through the mobile app.</td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row9_col1" class="data row9 col1" >0.210798</td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row9_col2" class="data row9 col2" >0.251833</td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row9_col3" class="data row9 col3" >0.118517</td>
#             </tr>
#             <tr>
#                         <th id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row10_col0" class="data row10 col0" >I notice that course materials on Canvas have connection with the face to face (classroom) lesson content.</td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row10_col1" class="data row10 col1" >0.179135</td>
#                         <td id="T_cc6db1b6_87e8_11eb_bb39_e299a02a39e1row10_col2" class="data row10 col2"

# %%
cor_num.to_csv("Sentiment_Comparison.csv",index=False)
