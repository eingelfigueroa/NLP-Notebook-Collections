# %% [markdown]
# ### Extract Aspect from three qualitative question from GenEd

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (3.5)
# Requirement already satisfied: click in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from nltk) (7.1.2)
# Requirement already satisfied: tqdm in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from nltk) (4.59.0)
# Requirement already satisfied: regex in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from nltk) (2021.3.17)
# Requirement already satisfied: joblib in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from nltk) (1.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import re
import nltk
import ast
from nltk import word_tokenize, pos_tag, pos_tag_sents

# %%
nltk.download('vader_lexicon')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger') 
nltk.download('punkt')
nltk.download('wordnet')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords


from nltk.stem import WordNetLemmatizer 
from nltk.corpus import wordnet 
# Create WordNetLemmatizer object 


lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/jupyterlab/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/jupyterlab/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/jupyterlab/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to /home/jupyterlab/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/jupyterlab/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df = pd.read_csv('Cleaned_CES_Pre_1st.csv')
second_df = pd.read_csv('Cleaned_CES_Final_1st.csv')
df = df.replace(np.nan, 'Neutral', regex=True) ### Some values are missing, use "Neutral" for missing values
df = df.drop(df.columns[[0]],axis=1) ### Drop extra index
test_df = df.iloc[0:, 0:] # Just for renaming purposes so that df variable can be used for testing
frame = [df,second_df]
test_df = pd.concat(frame)
test_df
# Out:
#                                      SUBJECT:              SECTION:  \
# 0    HIS C101- Readings in Philippine History              BSA 101A
# 1    HIS C101- Readings in Philippine History                  103R
# 2    HIS C101- Readings in Philippine History                  101K
# 3    HIS C101- Readings in Philippine History                 102-F
# 4    HIS C101- Readings in Philippine History                  101M
# ..                                        ...                   ...
# 531  HIS C101- Readings in Philippine History                 101LM
# 532  HIS C101- Readings in Philippine History  101 legal management
# 533  HIS C101- Readings in Philippine History              BSTM 1-1
# 534  HIS C101- Readings in Philippine History                 101 P
# 535  HIS C101- Readings in Philippine History                 104TM
#
#     COURSE SCHEDULE I can easily log-in and log-out my Canvas account.  \
# 0          12:00 PM                                     Strongly Agree
# 1          12:18 PM                                           Disagree
# 2          01:30 PM                                     Strongly Agree
# 3          12:00 PM                                     Strongly Agree
# 4          10:30 AM                                     Strongly Agree
# ..              ...                                                ...
# 531        12:00 PM                                              Agree
# 532        12:00 PM                                     Strongly Agree
# 533         9:00 AM                                     Strongly Agree
# 534         9:00 AM                                     Strongly Agree
# 535         9:00 AM                                     Strongly Agree
#
#     I can access my course using the mobile Canvas app.  \
# 0                                       Strongly Agree
# 1                                             Disagree
# 2                                       Strongly Agree
# 3                                       Strongly Agree
# 4                                                Agree
# ..                                                 ...
# 531                                           Disagree
# 532                                     Strongly Agree
# 533                                     Strongly Agree
# 534                                     Strongly Agree
# 535                                     Strongly Agree
#
#     I can access my Canvas account using the available computers in JRU.  \
# 0                                       Strongly Agree
# 1                                             Disagree
# 2                                       Strongly Agree
# 3                                       Strongly Agree
# 4                                                Agree
# ..                                                 ...
# 531                                              Agree
# 532                                     Strongly Agree
# 533                                              Agree
# 534                                              Agree
# 535                                     Strongly Agree
#
#     I have no issues accessing my Canvas account using JRU's wifi connection.  \
# 0                                       Strongly Agree
# 1                                                Agree
# 2                                       Strongly Agree
# 3                                       Strongly Agree
# 4                                                Agree
# ..                                                 ...
# 531                                              Agree
# 532                                     Strongly Agree
# 533                                              Agree
# 534                                              Agree
# 535                                     Strongly Agree
#
#     I have no issues accessing my Canvas account using the wired internet connection in the computer laboratories.  \
# 0                                       Strongly Agree
# 1                                             Disagree
# 2                                       Strongly Agree
# 3                                       Strongly Agree
# 4                                                Agree
# ..                                                 ...
# 531                                              Agree
# 532                                     Strongly Agree
# 533                                              Agree
# 534                                              Agree
# 535                                     Strongly Agree
#
#     I can easily get help when I have problems with my Canvas account.  \
# 0                                       Strongly Agree
# 1                                                Agree
# 2                                       Strongly Agree
# 3                                       Strongly Agree
# 4                                                Agree
# ..                                                 ...
# 531                                              Agree
# 532                                     Strongly Agree
# 533                                              Agree
# 534                                              Agree
# 535                                     Strongly Agree
#
#     I can access my Canvas account outside JRU.  ...  \
# 0                                Strongly Agree  ...
# 1                                         Agree  ...
# 2                                Strongly Agree  ...
# 3                                Strongly Agree  ...
# 4                                         Agree  ...
# ..                                          ...  ...
# 531                                       Agree  ...
# 532                              Strongly Agree  ...
# 533                              Strongly Agree  ...
# 534                                       Agree  ...
# 535                              Strongly Agree  ...
#
#     Canvas has made it easy for me to: Share ideas on group discussions  \
# 0                                       Strongly Agree
# 1                                             Disagree
# 2                                             Disagree
# 3                                                Agree
# 4                                                Agree
# ..                                                 ...
# 531                                           Disagree
# 532                                     Strongly Agree
# 533                                              Agree
# 534                                     Strongly Agree
# 535                                     Strongly Agree
#
#     I can answer the assessment materials (quiz, exam) posted in Canvas.  \
# 0                                       Strongly Agree
# 1                                                Agree
# 2                                                Agree
# 3                                                Agree
# 4                                                Agree
# ..                                                 ...
# 531                                              Agree
# 532                                     Strongly Agree
# 533                                     Strongly Agree
# 534                                     Strongly Agree
# 535                                     Strongly Agree
#
#     I find the course materials on Canvas aligned with the: Quizzes  \
# 0                                       Strongly Agree
# 1                                                Agree
# 2                                                Agree
# 3                                                Agree
# 4                                       Strongly Agree
# ..                                                 ...
# 531                                              Agree
# 532                                     Strongly Agree
# 533                                     Strongly Agree
# 534                                     Strongly Agree
# 535                                     Strongly Agree
#
#     I find the course materials on Canvas aligned with the: Major (Prelim, Mideterm, Final) Exam  \
# 0                                       Strongly Agree
# 1                                                Agree
# 2                                       Strongly Agree
# 3                                                Agree
# 4                                       Strongly Agree
# ..                                                 ...
# 531                                              Agree
# 532                                     Strongly Agree
# 533                                     Strongly Agree
# 534                                     Strongly Agree
# 535                                     Strongly Agree
#
#     I find the course materials on Canvas aligned with the: Other tasks  \
# 0                                       Strongly Agree
# 1                                                Agree
# 2                                                Agree
# 3                                                Agree
# 4                                       Strongly Agree
# ..                                                 ...
# 531                                              Agree
# 532                                     Strongly Agree
# 533                                              Agree
# 534                                     Strongly Agree
# 535                                     Strongly Agree
#
#     I have been give enough time to accomplish the activities on Canvas.  \
# 0                                       Strongly Agree
# 1                                             Disagree
# 2                                       Strongly Agree
# 3                                                Agree
# 4                                                Agree
# ..                                                 ...
# 531                                              Agree
# 532                                     Strongly Agree
# 533                                              Agree
# 534                                     Strongly Agree
# 535                                     Strongly Agree
#
#                     What I like best in Canvas is/are:  \
# 0                                              Neutral
# 1                                              Neutral
# 2    I can easily answer my quizzes and other forum...
# 3                                    It can di at home
# 4       give me some extra grades in specific  course.
# ..                                                 ...
# 531                                                NaN
# 532                                                NaN
# 533                                                NaN
# 534                                                NaN
# 535                                                NaN
#
#                    What I like least in Canvas is/are:  \
# 0                                              Neutral
# 1                                              Neutral
# 2    Some announcement are not showing up in my not...
# 3    Some of the instructions are not fully underst...
# 4                                              Neutral
# ..                                                 ...
# 531                                                NaN
# 532                                                NaN
# 533                                                NaN
# 534                                                NaN
# 535                                                NaN
#
#                               I would like to suggest: Unnamed: 0
# 0                                              Neutral        NaN
# 1                                              Neutral        NaN
# 2    Create a power point moduel not a word and sum...        NaN
# 3    To be more active at face to face and lessen t...        NaN
# 4                                              Neutral        NaN
# ..                                                 ...        ...
# 531                                                NaN     2035.0
# 532                                                NaN     2037.0
# 533                                                NaN     2075.0
# 534                                                NaN     2082.0
# 535                                                NaN     2083.0
#
# [1067 rows x 36 columns]

# %%
test_df = test_df.iloc[0:, -4:-1]
test_df
# Out:
#                     What I like best in Canvas is/are:  \
# 0                                              Neutral
# 1                                              Neutral
# 2    I can easily answer my quizzes and other forum...
# 3                                    It can di at home
# 4       give me some extra grades in specific  course.
# ..                                                 ...
# 531                                                NaN
# 532                                                NaN
# 533                                                NaN
# 534                                                NaN
# 535                                                NaN
#
#                    What I like least in Canvas is/are:  \
# 0                                              Neutral
# 1                                              Neutral
# 2    Some announcement are not showing up in my not...
# 3    Some of the instructions are not fully underst...
# 4                                              Neutral
# ..                                                 ...
# 531                                                NaN
# 532                                                NaN
# 533                                                NaN
# 534                                                NaN
# 535                                                NaN
#
#                               I would like to suggest:
# 0                                              Neutral
# 1                                              Neutral
# 2    Create a power point moduel not a word and sum...
# 3    To be more active at face to face and lessen t...
# 4                                              Neutral
# ..                                                 ...
# 531                                                NaN
# 532                                                NaN
# 533                                                NaN
# 534                                                NaN
# 535                                                NaN
#
# [1067 rows x 3 columns]

# %%
stoplist = stopwords.words('english') + ['though']
def remove_stopWords(w): 
    w = ' '.join(word for word in w.split() if word not in stoplist)
    return w

# %%
## Reduce list dimension

def flatten_list(_2d_list):
    flat_list = []
    # Iterate through the outer list
    for element in _2d_list:
        if type(element) is list:
            # If the element is of type list, iterate through the sublist
            for item in element:
                flat_list.append(item)
        else:
            flat_list.append(element)
    return flat_list

# %%
col_range = len(test_df.columns) # number of columns
test_df = test_df.replace(r'^\s*$', "neutral", regex=True) ## If row value is null, replace with neutral string
aspect_list = []

for i in range(0,3):
    col = test_df.columns[i] # The current column
    test_df.loc[:,col] = test_df[col].apply(lambda x : str.lower(str(x))) ## To Lower Case
    test_df.loc[:,col] = test_df[col].apply(lambda x : " ".join(re.findall('[\w]+',x))) # Remove Punctuations
    test_df.loc[:,col] = test_df[col].apply(lambda x : remove_stopWords(x)) # Remove Stop words
    
    ##POS TAGGING
    texts = test_df.loc[:,col].tolist()
    tagged_texts = pos_tag_sents(map(word_tokenize, texts)) ### Tag every word in a row with POS
    
    #inputTupples=ast.literal_eval(tagged_texts)
    flattened_tagged = flatten_list(tagged_texts)
    prevWord=''
    prevTag=''
    currWord=''
    aspectList=[]
    outputDict={}
    
    #Extracting Aspects
    
    for word,tag in flattened_tagged:
        if(tag=='NN' or tag=='NNP'):
            if(prevTag=='NN' or prevTag=='NNP'):
                currWord= prevWord + ' ' + word
            else:
                aspectList.append(prevWord.upper())
                currWord= word

        prevWord=currWord
        prevTag=tag
    #Eliminating aspect which has 1 or less count
    for aspect in aspectList:
            if(aspectList.count(aspect)>1):
                    if(outputDict.keys()!=aspect):
                            outputDict[aspect]=aspectList.count(aspect)
    outputAspect=sorted(outputDict.items(), key=lambda x: x[1],reverse = True)
    aspect_list.append(outputAspect)
    #print(outputAspect)

# %%
df_cols = test_df.columns.tolist()

for i in range(0,col_range):
    print(i+1," ",df_cols[i])
    print(aspect_list[i], "\n")
# Out:
# 1   What I like best in Canvas is/are:
# [('ACCESS', 48), ('CANVAS', 18), ('USE', 16), ('TIME', 14), ('SCHOOL', 9), ('NAN', 9), ('ANSWER', 7), ('CONVENIENT', 6), ('NAN NAN', 6), ('ACCESS NAN', 6), ('COURSE', 5), ('LESSON', 5), ('ACCESSIBILITY', 5), ('ONLINE', 5), ('ANNOUNCEMENT', 4), ('QUIZ', 3), ('ADVANCE', 3), ('NONE', 3), ('HELP', 3), ('SUBMIT', 3), ('MEETING', 3), ('ACCESS CANVAS', 3), ('TASK', 3), ('ASSIGNMENT', 2), ('FACE FACE DISCUSSION', 2), ('ACCESS ACCOUNT', 2), ('EXAM', 2), ('ASSIGNMENT QUIZ', 2), ('UNIVERSITY', 2), ('CAMPUS', 2), ('PASSING', 2), ('THING', 2), ('USE ANYTIME', 2), ('TIME STUDY', 2), ('TIME PASS', 2), ('SYSTEM', 2), ('PASS', 2), ('CLASS', 2), ('STUDENT', 2), ('PAPER', 2), ('NAN QUIZ', 2), ('NAN NAN NAN NAN', 2), ('CALENDAR', 2), ('ACCESS NAN NAN', 2)]
#
# 2   What I like least in Canvas is/are:
# [('CANVAS', 22), ('TIME', 20), ('NONE', 14), ('DATE', 7), ('USE', 6), ('TIME LIMIT', 5), ('MODULE', 5), ('INTERNET', 5), ('NAN NAN', 5), ('NAN', 5), ('NOTHING', 4), ('INSTRUCTOR', 4), ('CODE', 4), ('INTERNET CONNECTION', 4), ('ACTIVITY', 4), ('PROFESSOR', 4), ('ANNOUNCEMENT', 3), ('NOTIFICATION', 3), ('QUIZ', 3), ('VERSION', 3), ('BUTTON', 3), ('UNDERSTAND', 3), ('APP', 3), ('WORK', 3), ('ACCESS CODE', 3), ('FORUM', 2), ('SEE', 2), ('ACCESS', 2), ('CLASS', 2), ('PASS', 2), ('SOMETHING', 2), ('PART', 2), ('TASK', 2), ('ONLINE', 2), ('HELP', 2), ('READ', 2), ('LIST', 2), ('ACCESS CANVAS', 2), ('ANSWER', 2), ('LOG', 2), ('PERFORMANCE', 2), ('HATE CANVAS', 2), ('UNDERSTAND LESSON', 2), ('NAN NAN NAN NAN NAN', 2)]
#
# 3   I would like to suggest:
# [('CANVAS', 35), ('TIME', 24), ('NOTHING', 10), ('NONE', 9), ('TIME LIMIT', 7), ('FACE FACE', 6), ('PLEASE', 6), ('USE', 6), ('WAY', 6), ('NAN', 6), ('DATE', 5), ('STUDENT', 5), ('TASK', 5), ('QUIZ', 5), ('APP', 4), ('MODULE', 4), ('SUGGESTION', 4), ('ACCESS CODE', 4), ('PRESENTATION', 4), ('ACCESS', 4), ('CODE', 4), ('NAN NAN', 4), ('PASS', 3), ('NOTIFICATION', 3), ('CONTINUE', 3), ('CANVAS APP', 3), ('INFORMATION', 3), ('LIST', 3), ('IMPROVEMENT', 3), ('INTERNET', 3), ('WIFI', 3), ('INTERNET CONNECTION', 3), ('CLASSROOM', 3), ('CALENDAR', 3), ('NONE NAN', 3), ('NAN NAN NAN NAN NAN', 3), ('CANVAS NAN', 3), ('PACKAGE', 2), ('LOT', 2), ('POINT', 2), ('MAKE', 2), ('FIX PROBLEM', 2), ('SUGGEST PROFESSOR', 2), ('PASSCODE', 2), ('SUBJECT', 2), ('ACCESS CANVAS', 2), ('READ', 2), ('PUT', 2), ('CAMPUS', 2), ('KIND', 2), ('WEEK', 2), ('MATTER', 2), ('POST', 2), ('DEADLINE', 2), ('HASSLE', 2), ('MATERIAL', 2), ('LESSON', 2), ('PROFESSOR DISCUSS', 2), ('INSTRUCTION', 2), ('PRESSURE', 2), ('PROFESSOR', 2)]
