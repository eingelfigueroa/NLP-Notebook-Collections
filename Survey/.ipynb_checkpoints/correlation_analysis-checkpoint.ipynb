# %%
import pandas as pd
import numpy as np
import scipy.stats

# %%
df = pd.read_csv('opinion_sentiment.csv')
corr = df.drop(df.columns[[1,2,3,4]],axis=1)
corr
# Out:
#                                                 index  Numerical Value  \
# 0   I can easily log-in and log-out my Canvas acco...             3.84
# 1   I can access my course using the mobile Canvas...             3.68
# 2   I can access my Canvas account using the avail...             3.83
# 3   I can easily get help when I have problems wit...             3.52
# 4   I have no issues accessing my Canvas account u...             3.67
# 5        I can access my Canvas account outside JRU.              3.81
# 6   I can clearly understand the lessons on my Can...             3.61
# 7   I recognize that the modules in my course are ...             3.78
# 8   I can easily manage the navigation of the cour...             3.82
# 9   I can easily manage the navigation of the cour...             3.54
# 10  I notice that course materials on Canvas have ...             3.61
# 11  I understand the lessons better with the help ...             3.66
# 12        Canvas course materials make me interested.             3.66
# 13  The course materials on Canvas helped me prepa...             3.73
# 14             My instructor knows how to use Canvas.             3.84
# 15  My instructor demonstrated mastery of the subj...             3.76
# 16         My instructor encourages me to use Canvas.             3.83
# 17  Canvas has made it easy for me to: [Communicat...             3.56
# 18  I can answer the assessment materials (quiz, e...             3.79
# 19  I find the course materials on Canvas aligned ...             3.74
# 20  I have been give enough time to accomplish the...             3.57
# 21  Canvas has made it easy for me to: [Receive cl...             3.83
# 22  Canvas has made it easy for me to: [Share idea...             3.67
# 23  I can answer the assessment materials (quiz, e...             3.79
# 24  I find the course materials on Canvas aligned ...             3.74
# 25  I find the course materials on Canvas aligned ...             3.76
# 26  I find the course materials on Canvas aligned ...             3.78
# 27  I have been give enough time to accomplish the...             3.57
#
#     Sentiment Score
# 0          0.148826
# 1          0.140744
# 2          0.141499
# 3         -0.007863
# 4          0.244604
# 5          0.155105
# 6          0.228990
# 7          0.242035
# 8          0.283602
# 9          0.210798
# 10         0.179135
# 11         0.335552
# 12         0.341187
# 13         0.254526
# 14         0.217584
# 15         0.258990
# 16         0.284222
# 17         0.286009
# 18         0.215716
# 19         0.180929
# 20         0.196451
# 21              NaN
# 22              NaN
# 23              NaN
# 24              NaN
# 25              NaN
# 26              NaN
# 27              NaN

# %%
#Aggregate Same Likert and Opinions first
# Manually fix inequal rows
'''
Numerical_mean  = corr.iloc[0:, 1].mean()
Sentiment_mean  = corr.iloc[0:, 2].mean()
means = [Numerical_mean,Sentiment_mean]
corr.loc[21] = ['Average'] + means
'''
                        ###Row  #Col
numerical_mean_first  = corr.iloc[13:17, 1].mean()
sentiment_mean_first = corr.iloc[13,2]

numerical_mean_sec  = corr.iloc[20:23, 1].mean()
sentiment_mean_sec = corr.iloc[20,2]

numerical_mean_third  = corr.iloc[24:27, 1].mean()
sentiment_mean_third = corr.iloc[24,2]

means1 = [numerical_mean_first,sentiment_mean_first]
corr.loc[29] = ['1st aggregation'] + means1

means2 = [numerical_mean_sec,sentiment_mean_sec]
corr.loc[30] = ['2nd aggregation'] + means2

means3 = [numerical_mean_third,sentiment_mean_third]
corr.loc[31] = ['3rd aggregation'] + means3

Numerical_mean  = corr.iloc[0:, 1].mean()
Sentiment_mean  = corr.iloc[0:, 2].mean()
means = [Numerical_mean,Sentiment_mean]
corr.loc[32] = ['Average'] + means

fixed_df = corr.drop([13,14,15,16,20,21,22,24,25,26])

fixed_df.reset_index(drop=True)
fixed_df.to_csv("fixed_numerical.csv", index=False)
fixed_df
# Out:
#                                                 index  Numerical Value  \
# 0   I can easily log-in and log-out my Canvas acco...         3.840000
# 1   I can access my course using the mobile Canvas...         3.680000
# 2   I can access my Canvas account using the avail...         3.830000
# 3   I can easily get help when I have problems wit...         3.520000
# 4   I have no issues accessing my Canvas account u...         3.670000
# 5        I can access my Canvas account outside JRU.          3.810000
# 6   I can clearly understand the lessons on my Can...         3.610000
# 7   I recognize that the modules in my course are ...         3.780000
# 8   I can easily manage the navigation of the cour...         3.820000
# 9   I can easily manage the navigation of the cour...         3.540000
# 10  I notice that course materials on Canvas have ...         3.610000
# 11  I understand the lessons better with the help ...         3.660000
# 12        Canvas course materials make me interested.         3.660000
# 17  Canvas has made it easy for me to: [Communicat...         3.560000
# 18  I can answer the assessment materials (quiz, e...         3.790000
# 19  I find the course materials on Canvas aligned ...         3.740000
# 23  I can answer the assessment materials (quiz, e...         3.790000
# 27  I have been give enough time to accomplish the...         3.570000
# 29                                    1st aggregation         3.790000
# 30                                    2nd aggregation         3.690000
# 31                                    3rd aggregation         3.760000
# 32                                            Average         3.717097
#
#     Sentiment Score
# 0          0.148826
# 1          0.140744
# 2          0.141499
# 3         -0.007863
# 4          0.244604
# 5          0.155105
# 6          0.228990
# 7          0.242035
# 8          0.283602
# 9          0.210798
# 10         0.179135
# 11         0.335552
# 12         0.341187
# 17         0.286009
# 18         0.215716
# 19         0.180929
# 23              NaN
# 27              NaN
# 29         0.254526
# 30         0.196451
# 31              NaN
# 32         0.216940

# %%
x_var = fixed_df.iloc[0:-1, 1]
y_var = fixed_df.iloc[0:-1, 2]
y_var
# Out:
# 0     0.148826
# 1     0.140744
# 2     0.141499
# 3    -0.007863
# 4     0.244604
# 5     0.155105
# 6     0.228990
# 7     0.242035
# 8     0.283602
# 9     0.210798
# 10    0.179135
# 11    0.335552
# 12    0.341187
# 17    0.286009
# 18    0.215716
# 19    0.180929
# 23         NaN
# 27         NaN
# 29    0.254526
# 30    0.196451
# 31         NaN
# Name: Sentiment Score, dtype: float64

# %%
pearson_r = scipy.stats.pearsonr(x_var, y_var) #Pearson Correlation Analysis
pearson_r = np.reshape(pearson_r, (1, 2))
corr_analysis = pd.DataFrame(pearson_r, columns=["R", "p-Value"])
corr_analysis
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-536c16aa884a> in <module>
# ----> 1 pearson_r = scipy.stats.pearsonr(x_var, y_var) #Pearson Correlation Analysis
#       2 pearson_r = np.reshape(pearson_r, (1, 2))
#       3 corr_analysis = pd.DataFrame(pearson_r, columns=["R", "p-Value"])
#       4 corr_analysis
#
# ~/conda/envs/python/lib/python3.6/site-packages/scipy/stats/stats.py in pearsonr(x, y)
#    3866     # [-5e210, 5e210, 3e200, -3e200]
#    3867     normxm = linalg.norm(xm)
# -> 3868     normym = linalg.norm(ym)
#    3869
#    3870     threshold = 1e-13
#
# ~/conda/envs/python/lib/python3.6/site-packages/scipy/linalg/misc.py in norm(a, ord, axis, keepdims, check_finite)
#     138     # Differs from numpy only in non-finite handling and the use of blas.
#     139     if check_finite:
# --> 140         a = np.asarray_chkfinite(a)
#     141     else:
#     142         a = np.asarray(a)
#
# ~/conda/envs/python/lib/python3.6/site-packages/numpy/lib/function_base.py in asarray_chkfinite(a, dtype, order)
#     484     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
#     485         raise ValueError(
# --> 486             "array must not contain infs or NaNs")
#     487     return a
#     488
#
# ValueError: array must not contain infs or NaNs
